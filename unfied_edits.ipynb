# %%
import pandas as pd
import os
from pathlib import Path

df = pd.read_excel("unified_dataset_freeze_2025.08.21_1259/unified.xlsx")
df['unify_comment'] = ''
df['action'] = ''

# %%
# Fix 2023

base_dir = Path("/Users/addison/OneDrive - SCCWRP/bight_tox/compare_2025.08.21/")
dir_2023 =  base_dir / "2023"
print(os.listdir(dir_2023))

pub_2023 = pd.read_excel(dir_2023 / "bight23summary.xlsx", sheet_name = "bight23summary")

df_2023 = df[df['surveyyear'] == 2023]

delete_candidates_2023 = ["2303-S210",
"NIWC-2023-SP",
"PG1788S.p",
"WSP003",
"23-09-105 to -108",
"2308-S170-S171",
"2308-S172-S173",
"2309-S197-S203",
"EOH082923_B23",
"NIWC-2023-EOH_Split",
"NIWC-2023-MG_Split",
"Split_EE_C1_TOX",
"ABC003"]


df_2023.loc[df_2023['toxbatch'].isin(delete_candidates_2023), 'unify_comment'] = "QA/RFNH3/CNEG/Intercal only. Don't publish."
df_2023.loc[df_2023['toxbatch'].isin(delete_candidates_2023), 'action'] = "DELETE"
df_2023.loc[df_2023['toxbatch'].isin(delete_candidates_2023)]
# Out:
# ['bight23summary.xlsx', 'bight23results.xlsx', 'compare-2023.xlsx']
#       objectid  surveyyear                                           lab  \
# 4380      4381        2023  Aquatic Bioassay and Consulting Laboratories
# 4383      4384        2023  Aquatic Bioassay and Consulting Laboratories
# 4545      4546        2023                                   EcoAnalysts
# 4547      4548        2023                                      Enthalpy
# 4549      4550        2023                                      Enthalpy
# 4550      4551        2023                                      Enthalpy
# 4557      4558        2023                                      Enthalpy
# 4623      4624        2023      Naval Information Warfare Center Pacific
# 4626      4627        2023      Naval Information Warfare Center Pacific
# 4627      4628        2023      Naval Information Warfare Center Pacific
# 4681      4682        2023                               Pacific EcoRisk
# ...

# %%
# Fix 2018

dir_2018 =  base_dir / "2018"
print(os.listdir(dir_2018))
# Out:
# ['compare-2018.xlsx', 'Bight_18_Sediment_Toxicity_Results.csv', 'Bight_18_Sediment_Toxicity_Results.xlsx', 'Bight_18_Sediment_Toxicity_Summary_Results_9058230620704627381.xlsx']

# %%
pub_2018 = pd.read_excel(dir_2018 / "Bight_18_Sediment_Toxicity_Summary_Results_9058230620704627381.xlsx")

df_2018 = df[df['surveyyear'] == 2018]

delete_candidates_2018 = ['18-07-105 to -106',
'18-08-021 to -022',
'BEOH072418',
'BMYT072418',
'03/02B18eea',
'03/02B18eea',
'03/02B18eea',
'03/02B18eea',
'7/27B18eea2',
'1807-S142-S143',
'1808-S092-S093']


df_2018.loc[df_2018['toxbatch'].isin(delete_candidates_2018), 'unify_comment'] = "QA/RFNH3/CNEG/Intercal only. Don't publish."
df_2018.loc[df_2018['toxbatch'].isin(delete_candidates_2018), 'action'] = "DELETE"
df_2018.loc[df_2018['toxbatch'].isin(delete_candidates_2018)]
# Out:
#       objectid  surveyyear                                           lab  \
# 3846      3847        2018                AMEC, Foster, & Wheeler / WOOD
# 3850      3851        2018                AMEC, Foster, & Wheeler / WOOD
# 4067      4068        2018  Aquatic Bioassay and Consulting Laboratories
# 4073      4074        2018  Aquatic Bioassay and Consulting Laboratories
# 4241      4242        2018       Los Angeles County Sanitation Districts
# 4245      4246        2018       Los Angeles County Sanitation Districts
# 4300      4301        2018                        Nautilus Environmental
# 4301      4302        2018                        Nautilus Environmental
#
#      stationid           toxbatch                    species  dilution  \
# 3846      0000  18-07-105 to -106     Eohaustorius estuarius       NaN
# 3850      0000  18-08-021 to -022  Mytilus galloprovincialis       NaN
# 4067      0000         BEOH072418     Eohaustorius estuarius       NaN
# ...

# %%
# Fix 2013

dir_2013 =  base_dir / "2013"
print(os.listdir(dir_2013))
# Out:
# ['compare-2013.xlsx', 'Bight_2013_Regional_Survey_Toxicity_Results_-692175966774049861.xlsx', 'Bight_13_Toxicity_Summary_Results2_-2502133100839271899.xlsx']

# %%
pub_2013 = pd.read_excel(dir_2013 / "Bight_13_Toxicity_Summary_Results2_-2502133100839271899.xlsx")

df_2013 = df[df['surveyyear'] == 2013]

# %%
STATIONS = [
    'B13-8040',
    'B13-8013',
    'B13-8014',
    'B13-8028',
    'B13-8030',
    'B13-8038',
    'B13-8036',
]

TOXBATCHES = [
    '1308-S268 to S274',
    '1308-S268 to S274',
    '1308-S268 to S274',
    '1308-S268 to S274',
    '1308-S268 to S274',
    '1308-S268 to S274',
    '1308-S268 to S274',
]

delete_2013 = pd.DataFrame({'stationid': STATIONS, 'toxbatch': TOXBATCHES})
delete_2013
# Out:
#   stationid           toxbatch
# 0  B13-8040  1308-S268 to S274
# 1  B13-8013  1308-S268 to S274
# 2  B13-8014  1308-S268 to S274
# 3  B13-8028  1308-S268 to S274
# 4  B13-8030  1308-S268 to S274
# 5  B13-8038  1308-S268 to S274
# 6  B13-8036  1308-S268 to S274

# %%
# Create a temporary 'key' Series in both dataframes to facilitate the multi-column match
df_2013['key'] = df_2013['stationid'].astype(str) + '_' + df_2013['toxbatch'].astype(str)
delete_2013['key'] = delete_2013['stationid'].astype(str) + '_' + delete_2013['toxbatch'].astype(str)

# Use the .isin() method to create a boolean mask
match_mask = df_2013['key'].isin(delete_2013['key'])

# Apply the condition to update the desired column in df_main
df_2013.loc[match_mask, 'unify_comment'] = "QA/RFNH3/CNEG/Intercal only. Don't publish."

# You can drop the temporary 'key' column after the update
df_2013 = df_2013.drop(columns='key')
delete_2013 = delete_2013.drop(columns='key')


# df_2013.loc[df_2013['toxbatch'].isin(delete_2013) & , 'unify_comment'] = "QA/RFNH3/CNEG/Intercal only. Don't publish."
# df_2013.loc[df_2013['toxbatch'].isin(delete_candidates_2013), 'action'] = "DELETE"
# df_2013.loc[df_2013['toxbatch'].isin(delete_candidates_2013)]
# Out:
# /var/folders/5b/h4bvk5pj1l569v2_1w51mfx00000gn/T/ipykernel_7405/717739891.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2013['key'] = df_2013['stationid'].astype(str) + '_' + df_2013['toxbatch'].astype(str)

# %%
from sqlalchemy import create_engine

eng = create_engine(
    "postgresql+psycopg://addison:@localhost/addison"
)

with eng.begin() as con:
    df.to_sql("uni_summary", con, schema="unified")
